# %%
#| hide
from snooper_pkg.core import *

# %% [markdown]
# # snooper_pkg
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install snooper_pkg in Development mode

# %% [markdown]
# ```sh
# # make sure snooper_pkg package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to snooper_pkg
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/sayanbanerjee32/snooper_pkg.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c sayanbanerjee32 snooper_pkg
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install snooper_pkg
# ```
#
#
# [repo]: https://github.com/sayanbanerjee32/snooper_pkg
# [docs]: https://sayanbanerjee32.github.io/snooper_pkg/
# [pypi]: https://pypi.org/project/snooper_pkg/
# [conda]: https://anaconda.org/sayanbanerjee32/snooper_pkg

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/sayanbanerjee32/snooper_pkg
# [docs]: https://sayanbanerjee32.github.io/snooper_pkg/
# [pypi]: https://pypi.org/project/snooper_pkg/
# [conda]: https://anaconda.org/sayanbanerjee32/snooper_pkg

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
